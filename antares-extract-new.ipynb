# %%
import pandas as pd
import json
import os
import scipy.io as sio
import numpy as np
import re

pd.set_option('display.max_columns', 50)

# %%
datapath='rawdata/'
datafiles=os.listdir(datapath)

# %%
exportfolder='cleandata'
try:
    os.mkdir(exportfolder)
except:
    print('folder exists already')

# loop over files
f=0
for datafile in datafiles:

    #if datafile!='pP015_EPHEX_2_1_maindata_Tue Apr 18 2023 11_21_36 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json':
    #    continue

    strIndices=[]
    for match in re.finditer('_', datafile):
        strIndices.append(match.start())
    
    #print(datapath+datafile)
    subject = int(datafile[2:strIndices[0]])

    #print((datafile[strIndices[1]+1:strIndices[1]+2]))
    visit =  int(datafile[strIndices[1]+1:strIndices[1]+2])

    experiment=datafile[strIndices[0]+1:strIndices[1]]
    if experiment!='EPHEX':
        continue

    print(datafile)

    # preprocess the files
    if (datafile[len(datafile)-3:len(datafile)]=='csv') | (datafile[len(datafile)-3:len(datafile)]=='txt'):
        print(datafile)
        #df = pd.read_csv(datapath+datafile)
        #del df
    else:
        with open(datapath+datafile, 'r') as file2open:
            data = json.load(file2open)
            maindata=data[0:len(data)-2]
            try:
                mouseraw=pd.read_json(data[len(data)-1])
                mousedata=[]
                for i, row in mouseraw.iterrows():
                    mousedata.append(row['mousedata'])
                mousedata=pd.DataFrame(mousedata)
                mousedata.columns=['time','x', 'y', 'circleIn', 'polyIn', 'limit']
                del mouseraw
            except:
                print(datafile + ': mouse data impossible to read')
            #df = pd.read_json(datapath+datafile)
        file2open.close()
        del data

    f=f+1
    if f>50:
        break
# Out:
# folder exists already
# pp001_EPHEX_1_2_mousedata_Mon Feb 13 2023 11_28_09 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp001_EPHEX_1_2_mousedata_Mon Feb 13 2023 11_28_09 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp001_EPHEX_2_1_mousedata_Fri Feb 17 2023 10_19_42 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp001_EPHEX_2_1_mousedata_Fri Feb 17 2023 10_19_42 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp001_EPHEX_4_2_maindata_Fri Apr 14 2023 11_27_37 GMT+0200.json
# pp002_EPHEX_1_2_maindata_Thu Feb 23 2023 11_59_33 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp002_EPHEX_1_2_maindata_Thu Feb 23 2023 11_59_33 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp002_EPHEX_2_1_mousedata_Mon Feb 27 2023 10_28_41 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp002_EPHEX_2_1_mousedata_Mon Feb 27 2023 10_28_41 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pP002_EPHEX_4_2_maindata_Wed Apr 19 2023 10_20_44 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp003_EPHEX_2_1_mousedata_Fri Mar 03 2023 11_02_57 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp003_EPHEX_2_1_mousedata_Fri Mar 03 2023 11_02_57 GMT+0100 (heure normale dΓÇÖEurope centrale).csv
# pp004_EPHEX_1_2_maindata_Mon Mar 06 2023 11_25_54 GMT+0100 (heure normale dΓÇÖEurope centrale).json
# pp005_EPHEX_1_2_maindata_Fri Mar 10 2023 12_56_19 GMT+0100 (heure normale dΓÇÖEurope centrale).json
# pp005_EPHEX_2_1_maindata_Mon Mar 13 2023 11_18_30 GMT+0100 (heure normale dΓÇÖEurope centrale).json
# pp006_EPHEX_1_2_maindata_Fri Mar 17 2023 12_49_18 GMT+0100 (heure normale dΓÇÖEurope centrale).json
# pp006_EPHEX_2_1_maindata_Mon Mar 20 2023 12_50_41 GMT+0100 (heure normale dΓÇÖEurope centrale).json
# pp008_EPHEX_1_2_maindata_Tue Mar 28 2023 11_07_37 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp008_EPHEX_2_1_maindata_Fri Mar 31 2023 09_38_07 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP008_EPHEX_4_2_maindata_Tue May 30 2023 09_34_35 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp009_EPHEX_1_2_maindata_Thu Mar 30 2023 12_03_26 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp009_EPHEX_2_1_maindata_Mon Apr 03 2023 11_16_50 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp009_EPHEX_2_1_maindata_Mon Apr 03 2023 11_16_50 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json: mouse data impossible to read
# pP009_EPHEX_4_2_maindata_Tue May 30 2023 12_24_07 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP010_EPHEX_1_2_maindata_Thu Apr 06 2023 12_11_59 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP010_EPHEX_2_1_maindata_Tue Apr 11 2023 12_36_32 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp010_EPHEX_4_1_maindata_20230626_1202.txt
# pp010_EPHEX_4_1_maindata_20230626_1202.txt
# pp011_EPHEX_1_2_maindata_Fri Apr 07 2023 11_09_43 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP011_EPHEX_2_1_maindata_Tue Apr 11 2023 11_03_42 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP011_EPHEX_2_1_maindata_Tue Apr 11 2023 11_03_42 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json: mouse data impossible to read
# pP012_EPHEX_1_2_maindata_Fri Apr 07 2023 12_48_59 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp012_EPHEX_2_1_maindata_Tue Apr 11 2023 09_08_33 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp013_EPHEX_1_2_maindata_Wed Apr 12 2023 09_58_05 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP013_EPHEX_2_1_maindata_Fri Apr 14 2023 10_20_52 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp013_EPHEX_4_2_maindata_Mon Jun 12 2023 11_22_08 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP014_EPHEX_1_2_maindata_Wed Apr 12 2023 12_10_19 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP014_EPHEX_2_1_maindata_Fri Apr 14 2023 09_16_51 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP014_EPHEX_4_2_maindata_Wed May 31 2023 10_53_02 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP015_EPHEX_1_2_maindata_Thu Apr 13 2023 10_55_37 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP015_EPHEX_2_1_maindata_Tue Apr 18 2023 11_21_36 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp015_EPHEX_4_1_maindata_20230615_1212.txt
# pp015_EPHEX_4_1_maindata_20230615_1212.txt
# pP016_EPHEX_1_2_maindata_Mon Apr 24 2023 09_41_04 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP016_EPHEX_1_2_maindata_Mon Apr 24 2023 09_41_04 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json: mouse data impossible to read
# pP016_EPHEX_1_2_maindata_Mon Apr 24 2023 09_46_12 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP016_EPHEX_1_2_maindata_Mon Apr 24 2023 09_46_12 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json: mouse data impossible to read
# pP016_EPHEX_2_1_maindata_Wed Apr 26 2023 10_21_44 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp016_EPHEX_4_1_maindata_20230614_1043.txt
# pp016_EPHEX_4_1_maindata_20230614_1043.txt
# pP017_EPHEX_1_2_maindata_Mon Apr 24 2023 11_11_42 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP017_EPHEX_1_2_maindata_Mon Apr 24 2023 11_11_42 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json: mouse data impossible to read
# pP017_EPHEX_2_1_maindata_Thu Apr 27 2023 09_05_57 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp017_EPHEX_4_1_maindata_20230620_0936.txt
# pp017_EPHEX_4_1_maindata_20230620_0936.txt
# pP018_EPHEX_1_2_maindata_Tue Apr 25 2023 10_35_54 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP018_EPHEX_2_1_maindata_Fri Apr 28 2023 11_08_24 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp018_EPHEX_4_1_maindata_20230623_1047.txt
# pp018_EPHEX_4_1_maindata_20230623_1047.txt
# pP019_EPHEX_1_2_maindata_Tue Apr 25 2023 12_01_38 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP019_EPHEX_1_2_maindata_Tue Apr 25 2023 12_01_38 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json: mouse data impossible to read
# pP019_EPHEX_1_2_maindata_Tue Apr 25 2023 12_17_10 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP019_EPHEX_2_1_maindata_Fri Apr 28 2023 13_20_49 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp019_EPHEX_4_1_maindata_20230615_1257.txt
# pp019_EPHEX_4_1_maindata_20230615_1257.txt
# pP020_EPHEX_1_2_maindata_Fri Apr 28 2023 10_19_27 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pP020_EPHEX_2_1_maindata_Wed May 03 2023 10_32_58 GMT+0200 (heure dΓÇÖe╠üte╠ü dΓÇÖEurope centrale).json
# pp020_EPHEX_4_1_maindata_20230620_1112.txt
# pp020_EPHEX_4_1_maindata_20230620_1112.txt
